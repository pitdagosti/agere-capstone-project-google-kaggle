# %% [markdown]
# # PROJECT. AGERE (Agentic Recruiter)
# -------
#
# Test agents here

# %%
# Add parent directory to Python path (needed for notebook in subfolder)
import sys
from pathlib import Path

project_root = Path().absolute().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Clean imports using package structure
from agents import root_agent, Agent, InMemoryRunner
import tools

print("✅ Agents and tools loaded successfully!")
# Out:
# ✅ ADK components imported successfully.
# ✅ ADK will auto-initialize client from environment variables
# ✅ Root Agent defined with custom CV tools.
# ✅ Agents and tools loaded successfully!

# %%
# Test that root_agent is available
print(f"Agent name: {root_agent.name}")
print(f"Agent model: {root_agent.model}")
print(f"Agent description: {root_agent.description}")

# You can now use the agent like this:
# runner = InMemoryRunner()
# response = runner.run(root_agent, "Your query here")
# Out:
# Agent name: read_CV_assistant
# Agent model: gemini-2.0-flash-exp
# Agent description: Agent to read and analyze CVs from the dummy_files_for_testing folder.
